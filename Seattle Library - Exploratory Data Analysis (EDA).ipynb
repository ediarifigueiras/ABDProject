# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Context

# %% [markdown]
# **Column Description**
#
#
# | Column     | Type       | Description |
# |--------  |---------  |: --------- |
# | **BibNum** | Integer | Customer ID |
# | **Title** | String | Whether the customer is a male or a female |
# | **Author** | String | Whether the customer is a senior citizen or not (1, 0) |
# | **ISBN** | String | Whether the customer has a partner or not (Yes, No) |
# | **PublicationYear** | String | Whether the customer has dependents or not (Yes, No) |
# | **Publisher** | String | Number of months the customer has stayed with the company |
# | **Subjects** | String | Whether the customer has a phone service or not (Yes, No) |
# | **ItemType** | String | Whether the customer has multiple lines or not (Yes, No, No phone service) |
# | **ItemCollection** | String | Customer’s internet service provider (DSL, Fiber optic, No) |
# | **FloatingItem** | String | Whether the customer has online security or not (Yes, No, No internet service) |
# | **ItemLocation** | String | Whether the customer has online backup or not (Yes, No, No internet service) |
# | **ReportDate** | String | Whether the customer has device protection or not (Yes, No, No internet service) |
# | **ItemCount** | String | Whether the customer has tech support or not (Yes, No, No internet service) |

# %%
from pyspark.sql.types import *

customSchema = StructType([
  StructField("BibNum", IntegerType(), True),
  StructField("Title", StringType(), True),
  StructField("Author", StringType(), True),
  StructField("ISBN", StringType(), True),
  StructField("PublicationYear", StringType(), True),
  StructField("Publisher", StringType(), True),
  StructField("Subjects", StringType(), True),
  StructField("ItemType", StringType(), True),
  StructField("ItemCollection", StringType(), True),
  StructField("FloatingItem", StringType(), True),
  StructField("ItemLocation", StringType(), True),
  StructField("ReportDate", StringType(), True),
  StructField("ItemCount", StringType(), True)]
)

# %%
df = spark.read.format("csv")\
.option("header", "true")\
.schema(customSchema)\
.load("seattle-library-sample.csv")

# %%
df.dataframeName='seattle-library-sample'

# %%
df.cache()
# Out:
# DataFrame[BibNum: int, Title: string, Author: string, ISBN: string, PublicationYear: string, Publisher: string, Subjects: string, ItemType: string, ItemCollection: string, FloatingItem: string, ItemLocation: string, ReportDate: string, ItemCount: string]

# %%
print("Number of rows: " + str(df.count()))
# Out:
# Number of rows: 347484

# %%
cols = df.columns
print("Number of columns: " + str(len(cols)))
# Out:
# Number of columns: 13

# %%
df.printSchema()
# Out:
# root
#  |-- BibNum: integer (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Author: string (nullable = true)
#  |-- ISBN: string (nullable = true)
#  |-- PublicationYear: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Subjects: string (nullable = true)
#  |-- ItemType: string (nullable = true)
#  |-- ItemCollection: string (nullable = true)
#  |-- FloatingItem: string (nullable = true)
#  |-- ItemLocation: string (nullable = true)
#  |-- ReportDate: string (nullable = true)
#  |-- ItemCount: string (nullable = true)

# %%
#df.show(20,False)
#df.show()
df.show(n=2)
# Out:
# +------+--------------------+--------------------+----------+---------------+--------------------+--------------------+--------+--------------+------------+------------+--------------------+---------+
# |BibNum|               Title|              Author|      ISBN|PublicationYear|           Publisher|            Subjects|ItemType|ItemCollection|FloatingItem|ItemLocation|          ReportDate|ItemCount|
# +------+--------------------+--------------------+----------+---------------+--------------------+--------------------+--------+--------------+------------+------------+--------------------+---------+
# |  6845|Autumn of glory; ...|Connelly, Thomas ...|0807104450|         [1971]|Louisiana State U...|Confederate State...|    acbk|          canf|          NA|         cen|2017-09-01T00:00:...|        1|
# |  7118|Variety music cav...|Mattfeld, Julius,...|0139407189|         [1971]|       Prentice-Hall|Popular music Uni...|    arbk|         caref|          NA|         cen|2017-09-01T00:00:...|        1|
# +------+--------------------+--------------------+----------+---------------+--------------------+--------------------+--------+--------------+------------+------------+--------------------+---------+
# only showing top 2 rows

# %%
#df.filter(df.ItemCollection == "cchol").show(truncate=False)
#df.select("Subjects").where("ItemCollection"=="a")
#df.select("Subjects").filter("ItemCollection = 'cchol'").show()
df.select("Subjects").filter("ItemCollection = 'cchol'").show(truncate=False)
# Out:
# +--------------------+
# |            Subjects|
# +--------------------+
# |[Folklore Austria...|
# |[Moles Animals Ju...|
# |[Christmas poetry...|
# |[Groundhog Day Ju...|
# |[Fear Juvenile fi...|
# |[Mice Juvenile fi...|
# |[Memorial Day Juv...|
# |[Ballets Stories ...|
# |[Christmas Fictio...|
# |[Kwanzaa Juvenile...|
# |[Lambchop Stanley...|
# |[Ghosts Fiction, ...|
# |[Snowmen Juvenile...|
# |[Individuality Ju...|
# |[Christmas decora...|
# |[Valentines Day J...|
# |[Easter Bunny Juv...|
# |[Childrens songs ...|
# |[Stories in rhyme...|
# |[All Souls Day Me...|
# +--------------------+
# only showing top 20 rows

# %%
#df.show(truncate=False)
df.select("Subjects").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Subjects                                                                                                                                                                                                        |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Confederate States of America Army Department of Tennessee, United States History Civil War 1861 1865 Regimental histories                                                                                      |
# |Popular music United States Bibliography, Music United States Chronology                                                                                                                                        |
# |Historical fiction American Bibliography, Historical fiction English Bibliography, United States History Colonial period ca 1600 1775 Fiction Bibliography                                                      |
# |Erotica, Obscenity Law United States, Pornography Social aspects                                                                                                                                                |
# |Electronics Dictionaries, English language Dictionaries Spanish, Electronics Dictionaries Spanish, Spanish language Dictionaries English, Telecommunication Dictionaries, Telecommunication Dictionaries Spanish|
# |Tannenberg Battle of Stebark Poland 1914 Fiction, War fiction, Historical fiction                                                                                                                               |
# |Slavery United States, Slavery and the church United States, Slavery and the church Presbyterian Church                                                                                                         |
# |Palynology United States Congresses, Palynology Canada Congresses, Paleobotany Cretaceous Congresses, Paleobotany Tertiary Congresses                                                                           |
# |Chinese poetry Translations into English                                                                                                                                                                        |
# |Money, Foreign exchange, Gold standard                                                                                                                                                                          |
# |Fantasy, Stories in rhyme                                                                                                                                                                                       |
# |Circus Poetry, Stories in rhyme, Fantasy                                                                                                                                                                        |
# |Winlock Wash History                                                                                                                                                                                            |
# |Water resources development Raft River Watershed Utah and Idaho, Groundwater Raft River Watershed Utah and Idaho                                                                                                |
# |National Airlines inc                                                                                                                                                                                           |
# |Knappton Wash History                                                                                                                                                                                           |
# |English literature, American literature                                                                                                                                                                         |
# |Europe History 1789 1900 Sources, Europe History 20th century                                                                                                                                                   |
# |Lamy John Baptist 1814 1888                                                                                                                                                                                     |
# |Roethke Theodore 1908 1963 Criticism and interpretation                                                                                                                                                         |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
from pyspark.sql.types import ArrayType, IntegerType
from pyspark.sql.functions import split

df=df.withColumn(
    "Subjects",
    split(col("Subjects"), ",\s*").cast(ArrayType(StringType())).alias("Subjects")
)

# %%
#df.printSchema()
#df.select("Subjects").show(truncate=False)
#show(n=1, truncate=False)
lista = df.select("Subjects").collect()

# %%
lista[0][0][0]
# Out:
# 'Confederate States of America Army Department of Tennessee'

# %% [markdown]
# ## Data cleansing / preparation

# %%
# checking nulls
df.dropna().count()
# Out:
# 246464

# %%
#df.na.df.show()
from pyspark.sql.functions import isnan, when, count, col
df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# +------+-----+------+-----+---------------+---------+--------+--------+--------------+------------+------------+----------+---------+
# |BibNum|Title|Author| ISBN|PublicationYear|Publisher|Subjects|ItemType|ItemCollection|FloatingItem|ItemLocation|ReportDate|ItemCount|
# +------+-----+------+-----+---------------+---------+--------+--------+--------------+------------+------------+----------+---------+
# |     0| 1843| 54965|80224|           4477|     2954|    8322|     125|           118|         114|         109|       111|      112|
# +------+-----+------+-----+---------------+---------+--------+--------+--------------+------------+------------+----------+---------+

# %%
df.select([count(when(isnan('Subjects') | col('Subjects').isNull() , True))]).show()
# Out:
# +----------------------------------------------------------------------+
# |count(CASE WHEN (isnan(Subjects) OR (Subjects IS NULL)) THEN true END)|
# +----------------------------------------------------------------------+
# |                                                                     0|
# +----------------------------------------------------------------------+

# %%
df.where(col("Subjects").isNull()).count() # check null values
# Out:
# 8322

# %%
df.where(col("ItemType").isNull()).count() # check null values
# Out:
# 125

# %%
df.where(col("ItemCollection").isNull()).count() # check null values
# Out:
# 118

# %%
df.count()
# Out:
# 355806

# %%
df = df.na.drop(subset=["Subjects"]) ## Drop null values

# %%
df.where(col("Subjects").isNull()).count() # check null values
# Out:
# 0

# %%
df.count() # check number of rows
# Out:
# 347484

# %%
# columns
# Rever isto
cols_non_features = ["ReportDate","Publisher","PublicationYear","BibNum","ISBN",""]

# %% [markdown]
# ## Analyzing

# %%
from pyspark.sql.functions import count
df.select(count("ItemType")).show()
df.select(count("ItemCollection")).show()
# Out:
# +---------------+
# |count(ItemType)|
# +---------------+
# |         355681|
# +---------------+
#
# +---------------------+
# |count(ItemCollection)|
# +---------------------+
# |               355688|
# +---------------------+

# %%
from pyspark.sql.functions import countDistinct
df.select(countDistinct("ItemType")).show()
df.select(countDistinct("ItemCollection")).show()
# Out:
# +------------------------+
# |count(DISTINCT ItemType)|
# +------------------------+
# |                     674|
# +------------------------+
#
# +------------------------------+
# |count(DISTINCT ItemCollection)|
# +------------------------------+
# |                           594|
# +------------------------------+

# %%
from pyspark.sql.functions import first, last
df.select(first("ItemType"), last("ItemType")).show()
# Out:
# +---------------+--------------+
# |first(ItemType)|last(ItemType)|
# +---------------+--------------+
# |           acbk|          acbk|
# +---------------+--------------+

# %%
from pyspark.sql.functions import collect_set, collect_list
df.agg(collect_set("ItemCollection"), collect_list("ItemCollection")).show(20,True)
# Out:
# +---------------------------+----------------------------+
# |collect_set(ItemCollection)|collect_list(ItemCollection)|
# +---------------------------+----------------------------+
# |       [naesl, Elephants...|        [canf, canf, care...|
# +---------------------------+----------------------------+

# %%
from pyspark.sql.functions import  collect_list
df.agg(collect_set("ItemCollection")).show(20,False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |collect_set(ItemCollection)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[naesl, Elephants Juvenile fiction, Games Juvenile fiction, Elephants Fiction, Games Fiction, Picture books for children, ccln, naesli, Airplanes Piloting, Private investigators Great Britain Drama, ccfft, Actors Soviet Union Biography, cadesk7, Compulsive behavior Fiction", Kennedy John F John Fitzgerald 1917 1963 Last years and death, Biographies, nalpfic, Fitch family, Poets Russian 19th century Biography", Chicago Ill Fiction, Pressure cooking, Electric cooking, High protein diet Recipes, Gluten free diet Recipes, Prehistoric peoples Nutrition, Cooking Natural foods, Quick and easy cooking, Electric cooking Slow, Cookbooks, cccd, cs7ro, Childrens stories Russian Juvenile fiction, Hudson Street Press,, SpongeBob SquarePants Fictitious character Juvenile fiction, Rock groups Juvenile fiction, 2002.", cs7a, caaeroc, acmus, Women Sexual behavior History, Female orgasm History, Anorgasmy History, Masturbation History, Vibrators History, Physical education for women Sexual behavior History, 2002., cccomic, Krazy Kat Fictitious character Comic books strips etc, Ignatz Mouse Fictitious character Comic books strips etc, Comic books strips etc, nceck, H. Bechhold, cs9sxo, caslide, 1882230124, Magpies Juvenile fiction, cs7rf, Partiia sotsialistov revoliutsionerov History, pknf, nyb, Celebrities Comic books strips etc, Graphic novels, Comic books strips etc, Bin Laden Osama 1957 2011 Assassination, United States Navy SEALs History 21st century, United States Naval Special Warfare Development Group, Special operations Military science Pakistan, Special operations Military science United States, camus, 2006.", Beekeepers Drama, Families Italy Drama, Reality television programs Drama, Feature films, Fiction films, Coming of age films, Motion pictures Italian, Interior decoration", Televisa Home Entertainment ; Vivendi Entertainment,, Schuylkill County Pa History, cacd, nybocd, Science fiction, Short stories, Romantic suspense fiction", Alaska History To 1867, napar, Russia Federation Politics and government 1991, nynf, Criterion Collection,, Abstracts of title Pennsylvania Lancaster County, Lancaster County Pa Genealogy, Actors Soviet Union Biography", WGBH Educational Foundation,, calnr, Dog adoption, Service dogs, Social behavior in animals, Human animal communication, Human animal relationships, Large type books, calncd, Poetry", casea, cs9r, Adventure fiction", ccref, Public buildings United States, Building laws United States, Government property United States, Public works Law and legislation United States, Romance fiction", 2016., June 14, Russia History 1613 1689 Fiction", ncnew, Popular music Fake books, naaanew, naaafic, Drew Nancy Fictitious character Comic books strips etc, Internal combustion engines Comic books strips etc, Automobiles Fuel consumption Comic books strips etc, Dresses Comic books strips etc, Kidnapping Comic books strips etc, Graphic novels, Comics Graphic works, Susquehannah Company, Land tenure Pennsylvania Wyoming Valley, Landowners Pennsylvania Wyoming Valley Registers, Deeds Pennsylvania Wyoming Valley, Registers of births etc Pennsylvania Wyoming Valley, Susquehanna Claim 1753 1808, Public lands Pennsylvania, Public lands Connecticut, Wyoming Valley Pa Genealogy, Wyoming Valley Pa History Sources, Health behavior China, Longevity, Medicine Chinese, Lullabies Russian, Figure skating Soviet Union History, Pressure cooking, Electric cooking, High protein diet Recipes, Gluten free diet Recipes, Prehistoric peoples Nutrition, Cooking Natural foods, Quick and easy cooking, Electric cooking Slow, Smart cookers, Cookbooks, cs7r, Comedians United States Biography", 10% and 12% from one day to five years also days of grace: 33, cadesk5, Animals Juvenile fiction, Stories in rhyme, Animals Fiction, Stories in rhyme, Violence in children Russia Federation Fiction", nycomic, cavalo, cs8r, Rudd family, Rudd William 1789 1835 Family, England Genealogy, cavidnf, cs8x, arbk, Chechnia Russia History Civil War 1994 Fictio ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
from pyspark.sql.functions import  collect_list
df.agg(collect_list("ItemCollection")).show(1,True)
# Out:
# +----------------------------+
# |collect_list(ItemCollection)|
# +----------------------------+
# |        [canf, canf, care...|
# +----------------------------+

# %%
df.groupBy("Subjects", "ItemType", "ItemCollection").count().show()
# Out:
# +--------------------+--------+--------------+-----+
# |            Subjects|ItemType|ItemCollection|count|
# +--------------------+--------+--------------+-----+
# |African American ...|    arbk|          cabr|    1|
# |Sports cars Great...|    arbk|          cs7r|    2|
# |Edmonds Wash History|    arbk|         caref|    2|
# |American bison, W...|    arbk|          cs9r|    1|
# |Pirates Juvenile ...|    jcbk|          ncef|    3|
# |Architecture Comp...|    acbk|          canf|    1|
# |Finance Personal ...|    jcbk|          ccnf|    1|
# |Grunge music, Roc...|    accd|        naover|    3|
# |Boston Tea Party ...|    jcbk|          ncnf|    3|
# |Thought and think...|    acbk|          nanf|    2|
# |Animals Fiction, ...|    jcbk|         ncpic|    6|
# |Young women Ficti...|    acbk|       nalpfic|    1|
# |Popular instrumen...|    accd|          cacd|    1|
# |Fathers and sons ...|    acbk|         nafic|    3|
# |Probabilities, Ch...|    acbk|          nanf|    1|
# |Gorilla Juvenile ...|    jcbk|         ncpic|    1|
# |  Croatia Guidebooks|    acbk|          nanf|    2|
# |Murder Investigat...|    acbk|         canew|    1|
# |Sulzberger C L Cy...|    acbk|           cab|    1|
# |English literatur...|    acbk|          canf|    3|
# +--------------------+--------+--------------+-----+
# only showing top 20 rows

# %%
from pyspark.sql.functions import count, expr
df.groupBy("ItemCollection").agg(
countDistinct("ItemType").alias("DistinctItemTypes"),
expr("count(ItemType)")).show()
# Out:
# +--------------------+-----------------+---------------+
# |      ItemCollection|DistinctItemTypes|count(ItemType)|
# +--------------------+-----------------+---------------+
# |Feynman Richard P...|                1|              2|
# |               cceck|                1|              3|
# |               ccfft|                1|            493|
# |       Kondo, Robert|                1|              1|
# |               jcdvd|                1|              1|
# |               1947.|                0|              0|
# |     Philomel Books,|                1|              4|
# |Drew Nancy Fictit...|                1|              1|
# |    Adultery Fiction|                1|              1|
# |              carefo|                1|            168|
# |              cavalo|                2|             34|
# |                nccd|                3|           1322|
# |                cs6r|                6|           3990|
# |Physical fitness,...|                1|              1|
# |Private investiga...|                1|              2|
# |Chechnia Russia H...|                1|              2|
# |Motion pictures S...|                1|              1|
# |Actors Soviet Uni...|                1|              1|
# |               nahol|                3|             59|
# |Women slaves Unit...|                1|              1|
# +--------------------+-----------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ## Feature Transformation

# %%
from pyspark.ml.feature import OneHotEncoder, StringIndexer
encoder = OneHotEncoder()\
.setInputCol("ItemType")\
.setOutputCol("ItemType")

# %%
#encoder.transform(df.select("ItemType")).show()
#encoder.show()

# %%
stringIndexer = StringIndexer(inputCol="ItemType", outputCol="ItemTypeIndex")

# %%
model = stringIndexer.fit(df)

# %%
indexed = model.transform(df)
#indexed.show()
#encoder = OneHotEncoder(inputCol="categoryIndex", outputCol="categoryVec")
#encoded = encoder.transform(indexed)
#encoded.show()
indexed.select("ItemType","ItemTypeIndex").show()
# Out:
# +--------+-------------+
# |ItemType|ItemTypeIndex|
# +--------+-------------+
# |    acbk|          0.0|
# |    arbk|          2.0|
# |    arbk|          2.0|
# |    acbk|          0.0|
# |    arbk|          2.0|
# |    acbk|          0.0|
# |    acbk|          0.0|
# |    arbk|          2.0|
# |    acbk|          0.0|
# |    arbk|          2.0|
# |    jcbk|          1.0|
# |    jcbk|          1.0|
# |    arbk|          2.0|
# |    arbk|          2.0|
# |    arbk|          2.0|
# |    arbk|          2.0|
# |    acbk|          0.0|
# |    arbk|          2.0|
# |    acbk|          0.0|
# |    acbk|          0.0|
# +--------+-------------+
# only showing top 20 rows

# %%
#replace_cols = [ 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#                'TechSupport','StreamingTV', 'StreamingMovies']
#for i in replace_cols : 
#    df  = df.select(i).replace(["No internet service"], ["No"], i)

# %%
#from pyspark.sql.functions import regexp_replace, col
#replace_cols = [ 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#                'TechSupport','StreamingTV', 'StreamingMovies']
#for i in replace_cols :
#    df = df.withColumn(i, regexp_replace(i, "No internet service", "No"))

# %%
from pyspark.ml.feature import RFormula
supervised = RFormula(formula="label ~ . + ItemType:Subjects + ItemType:ItemLocation + ItemType:Author")

# %%
#fittedRF = supervised.fit(df)
#preparedDF = fittedRF.transform(df)
#preparedDF.show(1)
df.select("Subjects").show()
# Out:
# +--------------------+
# |            Subjects|
# +--------------------+
# |Confederate State...|
# |Popular music Uni...|
# |Historical fictio...|
# |Erotica, Obscenit...|
# |Electronics Dicti...|
# |Tannenberg Battle...|
# |Slavery United St...|
# |Palynology United...|
# |Chinese poetry Tr...|
# |Money, Foreign ex...|
# |Fantasy, Stories ...|
# |Circus Poetry, St...|
# |Winlock Wash History|
# |Water resources d...|
# |National Airlines...|
# |Knappton Wash His...|
# |English literatur...|
# |Europe History 17...|
# |Lamy John Baptist...|
# |Roethke Theodore ...|
# +--------------------+
# only showing top 20 rows

# %%
train, test = preparedDF.randomSplit([0.7, 0.3]) ## preparing dataframe

# %% [markdown]
# ## Classification

# %%
from pyspark.ml.classification import LogisticRegression

# %%
train_df, test_df = df.randomSplit([0.7, 0.3])
